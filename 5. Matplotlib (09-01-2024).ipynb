# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
# x axis values
x = [1,2,3]
# y axis values
y = [2,4,1]
# plotting the points
plt.plot(x,y)
# naming the x axis
plt.xlabel('x-axis')
# naming the yaxis
plt.ylabel('y-axis')
plt.title("LINE GRAPH")
plt.show()

# %%
import matplotlib.pyplot as plt
# x axis values
x = [1,2,3]
# y axis values
y = [2,4,1]
# plotting the points
plt.bar(x,y)
# naming the x axis
plt.xlabel('x-axis')
# naming the yaxis
plt.ylabel('y-axis')
plt.title("BAR GRAPH")
plt.show()

# %%
# Sin graph


import numpy as np 
x  = np.arange(0,10,0.1)
y = np.sin(x)

# figures in matplotlib using figure()
plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.show()

# %%
# cos graph

import numpy as np 
x  = np.arange(0,10,0.1)
y = np.cos(x)

# figures in matplotlib using figure()
plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.show()

# %%
# tan graph


import numpy as np 
x  = np.arange(0,10,0.1)
y = np.tan(x)

# figures in matplotlib using figure()
plt.figure(figsize=(6,4))
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Subplot

# %%
#plot 1 

x=np.array([0,1,2,3])
y=np.array([3,8,1,10])  
plt.subplot(2,2,1)
plt.plot(x,y)

#plot 2

x=np.array([0,1,2,3])
y=np.array([10,20,30,40])  
plt.subplot(2,2,2)
plt.plot(x,y)

#plot 3

x=np.array([0,1,2,3])
y=np.array([11,8,12,9])  
plt.subplot(2,2,3)
plt.plot(x,y)

#plot 4 

x=np.array([0,1,2,3])
y=np.array([13,8,12,10])  
plt.subplot(2,2,4)
plt.plot(x,y)

# %%
#plot-1
x = np.array([0,1,2,3])
y = np.array([3,8,1,10])
plt.subplot(2,2,1)
plt.plot(x,y)

#plot-2
x = np.array([0,1,2,3])
y = np.array([10,20,30,40])
plt.subplot(2,2,1)
plt.plot(x,y)

#plot-3
x = np.array([0,1,2,3])
y = np.array([11,28,19,24])
plt.subplot(2,2,1)
plt.plot(x,y)

#plot-4
x = np.array([0,1,2,3])
y = np.array([3,18,12,10])
plt.subplot(2,2,1)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np 
#marker is used to mark the points on the graph
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
#marker is used to mark the points on the graph
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,linestyle='dotted',marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
#marker is used to mark the points on the graph
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,linestyle='dotted',marker='*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
#marker is used to mark the points on the graph
# MS is use to increase or decrease the size of marker
# MEC is used to color the border of the marker
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,ms='20',marker='*',mec='r')
plt.show()

# %%
# marker is used to mark the points on the graph
# linestyle is used to plot the graph in dotted line
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,linestyle='dotted',marker='s')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
#marker is used to mark the points on the graph
# $$ is used for string

ypoints = np.array([3,8,1,10])
plt.plot(ypoints,ms='20',marker='$MY$',mec='r')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
# x axis values
x = [1,2,3,4,5]
# y axis values
y = [30,40,100,10,20]
# plotting the points
plt.scatter(x,y)
# naming the x axis
plt.xlabel('x-axis')
# naming the yaxis
plt.ylabel('y-axis')
plt.title("SCATTER GRAPH")
plt.show()

# %% [markdown]
# # Legends,labels and Titles

# %%
# Legends,labels and Titles

# values of x and y 

x = [5,10,15,20,25,30,35,40,45,50]
y = [1,4,3,2,7,6,9,8,10,5]

plt.plot(x,y,'g')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

# here we set the size for ticks,rotation and color value

plt.tick_params(axis="x",labelsize=18,labelrotation=-60,labelcolor="blue")
plt.tick_params(axis="y",labelsize=12,labelrotation=20,labelcolor="red")
plt.show()

# %%
x = [5,10,15,20,25,30,35,40,45,50]
y = [1,4,3,2,7,6,9,8,10,5]
plt.bar(x,y)
plt.title("Bar graph")

plt.xlabel("Time (hr)")
plt.ylabel("Position (km)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
# x axis values
x = [1,2,3]
# y axis values
y = [2,4,1]
# plotting the points
plt.bar(x,y)
# naming the x axis
plt.xlabel('Time(hr)')
# naming the yaxis
plt.ylabel('Distance(km)')
plt.title("BAR GRAPH")
plt.show()

# %%
y1 = [2,3,4,5]
y2 = [1,1.5,5]

# function to plot
plt.plot(y1)
plt.plot(y2)

# function add a legend
plt.legend(["blue","orange"],loc="lower right")

plt.show()

# %%
y1 = [2,3,4,5]
y2 = [1,1.5,5]

# function to plot
plt.plot(y1)
plt.plot(y2)

# function add a legend
plt.legend(["blue","orange"],loc="best")

plt.show()

# %% [markdown]
# # Histogram

# %%
data = np.random.normal(170,10,250)
#the hist() function will read the array and produce a histogram
# set the bin value 30
plt.hist(data)
plt.show()

plt.hist(data,bins=30)
plt.show()

# %%
fig, ax  = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

# text anotation
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))
ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=-90"))
# Out:
# Text(2, -6, 'local minimum')

# %% [markdown]
# # Pie Plot

# %%
# Creating dataset

cars = ['AUDI','BMW','FORD','TESLA','JAGUAR','MERCEDES']
data = [23,17,35,29,12,41]

# Creating plot
fig = plt.figure(figsize=(10,7))
plt.pie(data,labels=cars)
plt.show()

# %% [markdown]
# # Logarithmic

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(1, 10, 100)
y = np.log10(x)  # Logarithmic function, base 10

# Plot the data with logarithmic axes
plt.plot(x, y, label='Logarithmic Function')

# Set logarithmic scale for both x and y axes
plt.xscale('log')
plt.yscale('log')

# Add labels and title
plt.xlabel('X-axis (log scale)')
plt.ylabel('Y-axis (log scale)')
plt.title('Logarithmic Axes Example')

# Show the grid for better visualization
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Show the plot
plt.legend()
plt.show()

# %%
data = [10**i for i in range(5)]
plt.plot(data)

# %%
datax = [10**i for i in range(5)]
datay = [i for i in range(5)]
plt.xscale("log")
plt.plot(datax,datay)

# %% [markdown]
# # 3D Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()

ax = plt.axes(projection='3d')

z = np.linspace(0,1,1000)
x = z*np.sin(25 * z)
y = z*np.cos(25 * z)

ax.plot3D(x,y,z,'green')
ax.set_title('3D line plot')
plt.show()
# Out:
# C:\Users\Patel Kaushal\AppData\Local\Temp\ipykernel_11972\2033033497.py:13: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.plot3D(x,y,z,'green')

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection = "3d")

z = np.linspace(0,1,1000)
x = z * np.sin(25*z)
y = z * np.cos(25*z)

ax.plot3D(x,y,z,"blue")
ax.set_title("3-D Line Plot")
plt.show()
# Out:
# C:\Users\Patel Kaushal\AppData\Local\Temp\ipykernel_11972\716090491.py:9: MatplotlibDeprecationWarning: The clean function was deprecated in Matplotlib 3.8 and will be removed two minor releases later. Use none, you no longer need to clean a Grouper instead.
#   ax.plot3D(x,y,z,"blue")
